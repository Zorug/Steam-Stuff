# %% [markdown]
# <a href="https://colab.research.google.com/github/Zorug/Steam-Stuff/blob/master/collab_imshow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
a1 = plt.imread("https://lh6.googleusercontent.com/EyeYfSIaVjTO9cPpnEL7-XxrycFiXKA2731TUfe1187D_pMdDXtNKrpYIec9Fz067iAZEJ4uQafNeH9Q2iJNbaBsowEdMTpZHb_kqKa5PlWt7SXIwoNXQvHHk6ZBGhHfupmA3--kXA=w84-h84")
a2 = plt.imread("https://lh5.googleusercontent.com/pHybBQ8qPVn0ef-LlyWzTL7lSR-L35GY9brBRzY-rG9zfV9WvByro1PE30mdygSvnRmOox2Jg5bJG2B6OJnSRNVQq1uCaSNaoM0OHq0WelI8lULmsdsWYQlzqeEcdLpTCgXlxnICWg=w84-h84")
a3 = plt.imread("https://lh3.googleusercontent.com/_Wot9_1Zcar_VvbDoIqIi4_cxFo0xFwXgYoxm2pKCIzi10Vud9p9-JWlqJK3US85k5jb9tFHMVDuFoQYCou8wuM7vgoyTM0yIXet7YHodOoZy0HnBvlVAx7HiOnt19rd7a_mBMQNAw=w84-h84")
a4 = plt.imread("https://lh4.googleusercontent.com/FBH9JKWZGru6uanz0RgibmOqmRHnjOGd1KLEv4xRhIQuiPkPcJKQUnXvdWYEpZhkHQGToiOoxx2LgXpXVJTzOkdANRJH8kAieX5zgWdpBV0FUzq_8wqcOQnNNebuo0EW_kIldSfasw=w84-h84")

# %%
imagens_treino = [a1, a2, a3, a4]
#imagens_treino = imagens_treino/float(255)
plt.figure(figsize = (20,5))
for imagem in range(len(imagens_treino)):
  plt.subplot(1, 4, imagem+1)
  plt.imshow(imagens_treino[imagem])
  plt.title(imagem)
